# %%
import pandas as pd
import numpy as np
from ggplot import *

data = pd.DataFrame.from_csv("train.csv")
data['GrLivArea'] = data['GrLivArea'].apply(np.log)

# %%
p = ggplot(data,aes(y='SalePrice',x='GrLivArea'))
p + geom_point() + facet_wrap(x='Neighborhood')
# Out:
# <ggplot: (8736191935103)>

# %%
#ggplot(data,aes(x='Exterior1st',y='SalePrice', color='Exterior1st')) + geom_point()
qplot(x=data['Exterior1st'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     670                 type_pprinters=self.type_printers,
#     671                 deferred_pprinters=self.deferred_printers)
# --> 672             printer.pretty(obj)
#     673             printer.flush()
#     674             return stream.getvalue()
#
# /usr/lib/python3.5/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /usr/lib/python3.5/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
# ...

# %%
ggplot(data,aes(x='Neighborhood',y='SalePrice')) + geom_boxplot()

#print(data['SalePrice'][c=='Corner'].mean()/data['SalePrice'][c=='Inside'].mean())
# Out:
# <ggplot: (8785971089188)>
